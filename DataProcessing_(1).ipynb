# %% [markdown]
# # Convalescent Plasma Data Processing

# %% [markdown]
# ## Setup: Input Parameters and Variables

# %%
from io import StringIO
import csv
import pandas as pd
import os
from datetime import date, timedelta # Access to current date and time operations
# from datetime import datetime
from uuid import uuid4
import arcgis
import arcpy

# %% [markdown]
# ## Utilities

# %%
def process_facilities(input_excel, 
                       input_sheet_name,
                       address_field,
                       city_field,
                       state_field,
                       zipcode_field,
                       output_table_path,
                       output_fc_path,
                       address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                       facility_field=None,
                       symbology_layer=None,
                      ):
    
    ### GOAL: To geocode excel sheet with sites for ARC CCP Process
    # Sites may correspond to Blood Collection Sites or Plasma Distribution Sites
    
    # Convert excel sheet to FGDB table
    print("Converting to table...")
    table = arcpy.conversion.ExcelToTable(input_excel, 
                                          output_table_path, 
                                          input_sheet_name).getOutput(0)
    
    # Geocode FGDB Table using address fields
    print("Converting to facilities...")
    facilities_fc = arcpy.geocoding.GeocodeAddresses(table, 
                                                     address_locator, 
                                                     f"Address {address_field} VISIBLE NONE;City {city_field} VISIBLE NONE;State {state_field} VISIBLE NONE;ZIP_Code {zipcode_field} VISIBLE NONE", 
                                                     output_fc_path, 
                                                     "STATIC", None, '', 
                                                     "Subaddress;'Point Address';'Street Address';'Distance Marker';Intersection;'Street Name';'Primary Postal';'Postal Locality';'Postal Extension'").getOutput(0)
    
    # Add and calculate Facility_ID field
    print("Creating Facility ID field...")
    if facility_field:
        arcpy.management.CalculateField(facilities_fc, "FACILITY_ID", f"!{facility_field}!", "PYTHON3", '', "LONG")
    else:
        arcpy.management.CalculateField(facilities_fc, "FACILITY_ID", "!ObjectID!", "PYTHON3", '', "LONG")
    
    return facilities_fc

# %%
def process_incidents(input_excel, 
                      input_sheet_name,
                      address_field,
                      city_field,
                      state_field,
                      zipcode_field,
                      output_table_path,
                      output_fc_path,
                      address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                      incident_field=None,
                      symbology_layer=None):
    
    ### GOAL: To geocode excel sheet with incidents for ARC CCP Process
    # Incidents may correspond to Donor Leads or Plasma Need Locations
    
    # Convert excel sheet to FGDB table
    print("Converting to table...")
    table = arcpy.conversion.ExcelToTable(input_excel, 
                                          output_table_path, 
                                          input_sheet_name).getOutput(0)
    
    # Geocode FGDB Table using address fields
    print("Converting to incidents...")
    incidents_fc = arcpy.geocoding.GeocodeAddresses(table, 
                                                    address_locator, 
                                                    f"Address {address_field} VISIBLE NONE;City {arcpy.ValidateFieldName(city_field)} VISIBLE NONE;State {arcpy.ValidateFieldName(state_field)} VISIBLE NONE;ZIP_Code {arcpy.ValidateFieldName(zipcode_field)} VISIBLE NONE", 
                                                    output_fc_path, 
                                                    "STATIC", None, '', 
                                                    "Subaddress;'Point Address';'Street Address';'Distance Marker';Intersection;'Street Name';'Primary Postal';'Postal Locality';'Postal Extension'").getOutput(0)
    
    # Add and calculate Facility_ID field
    print("Creating Incident ID field...")
    if incident_field:
        arcpy.management.CalculateField(incidents_fc, "INCIDENT_ID", f"!{incident_field}!", "PYTHON3", '', "LONG")
    else:
        arcpy.management.CalculateField(incidents_fc, "INCIDENT_ID", "!ObjectID!", "PYTHON3", '', "LONG")
    
    return incidents_fc

# %%
def process_leads_csv(input_csv, 
                      address_field,
                      city_field,
                      state_field,
                      zipcode_field,
                      country_field,
                      workspace_fgdb,
                      output_table_name,
                      output_fc_path,
                      address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                      incident_field=None,
                      symbology_layer=None,
                      process_cohort_field=True,
                      cohort_field="Likely",
                      process_US_only=True
                     ):
    
    ### GOAL: To geocode csv with incidents for ARC CCP Process
    # Incidents may correspond to Donor Leads or Plasma Need Locations
    
    # Use csv reader to find csv header row
    print("Finding header row...")
    with open(input_csv) as fin:
        reader = csv.reader(fin)
        idx = next(idx for idx, row in enumerate(reader) if len(row)>1)
        
    # Use pandas to pre-process the csv
    df = pd.read_csv(input_csv, skiprows=idx)
    # If we need to convert non-"Yes" values to "No", perform the change
    print("\nCohort field value counts:")
    print(df[cohort_field].value_counts())
    if process_cohort_field:
        print("Processing cohort field...")
        df[cohort_field].mask(df[cohort_field] != "Yes", "No", inplace=True)
        print("New cohort value counts:")
        print(df[cohort_field].value_counts())
    
    print("\nCountry values:")
    print(df[country_field].value_counts())
    if process_US_only:
        print("Using United States records...")
        df = df.loc[df[country_field] == "United States"]
    
    print("\nExporting to local temp CSV...")
    temp_csv_name = "temp_{0}.csv".format(str(uuid4()))
    df.to_csv(temp_csv_name)

    # Convert excel sheet to FGDB table
    print("Converting to table...")
    table = arcpy.conversion.TableToTable(temp_csv_name, workspace_fgdb, output_table_name).getOutput(0)
    
    print("Removing temp CSV...")
    os.remove(temp_csv_name)
    
    # Geocode FGDB Table using address fields
    print("Converting to incidents...")
    incidents_fc = arcpy.geocoding.GeocodeAddresses(table, 
                                                    address_locator, 
                                                    f"Address {address_field} VISIBLE NONE;City {arcpy.ValidateFieldName(city_field)} VISIBLE NONE;State {arcpy.ValidateFieldName(state_field)} VISIBLE NONE;ZIP_Code {arcpy.ValidateFieldName(zipcode_field)} VISIBLE NONE", 
                                                    output_fc_path, 
                                                    "STATIC", None, '', 
                                                    "Subaddress;'Point Address';'Street Address';'Distance Marker';Intersection;'Street Name';'Primary Postal';'Postal Locality';'Postal Extension'").getOutput(0)
    
    # Add and calculate Facility_ID field
    print("Creating Incident ID field...")
    if incident_field:
        arcpy.management.CalculateField(incidents_fc, "INCIDENT_ID", f"!{incident_field}!", "PYTHON3", '', "LONG")
    else:
        arcpy.management.CalculateField(incidents_fc, "INCIDENT_ID", "!ObjectID!", "PYTHON3", '', "LONG")
    
    return incidents_fc

# %%
def process_connections(input_facilities_fc, 
                        input_incidents_fc,
                        output_fgdb,
                        output_connections_fc_name,
                        routing_nd, 
                        direction="TO_FACILITIES", # Alternative: "FROM_FACILITIES"
                       ):
    
    ### GOAL: To run network analysis between provided facilities and incidents for ARC CPP Process
    # Facilities and incidents can be part of Phase 1 (Donor Leads to Blood Collection Sites), or
    # Phase 2 (Distribution Sites to Care-givers with Need)
    
    # Make Closest Facility layer, using local road network
    print("Creating NA Object...")
    closest_facility_obj = arcpy.na.MakeClosestFacilityAnalysisLayer(routing_nd, 
                                                                     "ClosestFacility_{0}".format(date.today().strftime("%Y%m%d")),
                                                                     "Driving Time", "TO_FACILITIES", 
                                                                     None, 1, None, "LOCAL_TIME_AT_LOCATIONS", "START_TIME", 
                                                                     "ALONG_NETWORK", "Miles;TravelTime;WalkTime", "NO_DIRECTIONS")
    
    # Add Facilities
    print("Adding Facilities...")
    arcpy.na.AddLocations(closest_facility_obj, 
                          "Facilities", 
                          input_facilities_fc, 
                          "Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_TravelTime # 0;Attr_Miles # 0;Attr_Kilometers # 0;Attr_TimeAt1KPH # 0;Attr_WalkTime # 0;Attr_TruckMinutes # 0;Attr_TruckTravelTime # 0;Cutoff_Minutes # #;Cutoff_TravelTime # #;Cutoff_Miles # #;Cutoff_Kilometers # #;Cutoff_TimeAt1KPH # #;Cutoff_WalkTime # #;Cutoff_TruckMinutes # #;Cutoff_TruckTravelTime # #", 
                          "5000 Meters", None, 
                          "Routing_Streets SHAPE;Routing_Streets_Override NONE;Routing_ND_Junctions NONE", 
                          "MATCH_TO_CLOSEST", "CLEAR", "NO_SNAP", "5 Meters", "EXCLUDE", 
                          "Routing_Streets #;Routing_Streets_Override #;Routing_ND_Junctions #")
    
    # Add Incidents
    print("Adding Incidents...")
    arcpy.na.AddLocations(closest_facility_obj, 
                          "Incidents", 
                          input_incidents_fc, 
                          "Name # #;TargetFacilityCount # #;CurbApproach # 0;Attr_Minutes # 0;Attr_TravelTime # 0;Attr_Miles # 0;Attr_Kilometers # 0;Attr_TimeAt1KPH # 0;Attr_WalkTime # 0;Attr_TruckMinutes # 0;Attr_TruckTravelTime # 0;Cutoff_Minutes # #;Cutoff_TravelTime # #;Cutoff_Miles # #;Cutoff_Kilometers # #;Cutoff_TimeAt1KPH # #;Cutoff_WalkTime # #;Cutoff_TruckMinutes # #;Cutoff_TruckTravelTime # #", 
                          "5000 Meters", None, 
                          "Routing_Streets SHAPE;Routing_Streets_Override NONE;Routing_ND_Junctions NONE", 
                          "MATCH_TO_CLOSEST", "CLEAR", "NO_SNAP", "5 Meters", "EXCLUDE", 
                          "Routing_Streets #;Routing_Streets_Override #;Routing_ND_Junctions #")

    # Solve
    print("Solving...")
    arcpy.na.Solve(closest_facility_obj, "SKIP", "TERMINATE", None, '')  
    
    # Copy output routes to designated output fc
    print("Exporting connections to disk...")
    layer_object = closest_facility_obj.getOutput(0)
    sublayer_names = arcpy.na.GetNAClassNames(layer_object)
    print(sublayer_names)
#     connections_layer = sublayer_names["CFRoutes"]
#     arcpy.conversion.FeatureClassToFeatureClass(connections_layer, 
#                                                 output_fgdb, 
#                                                 output_connections_fc_name)
    connections_fc = arcpy.conversion.FeatureClassToFeatureClass("ClosestFacility_{0}/Routes".format(date.today().strftime("%Y%m%d")), 
                                                                 output_fgdb, 
                                                                 output_connections_fc_name).getOutput(0)
    
    return connections_fc

# %%
def post_process_connections_with_lead_info(connections_fc, leads_fc, 
                                            connections_id_field="IncidentID", leads_incident_id_field="ObjectID",
                                            cohort_field_name="Likely"):
    
    ### GOAL: To add the incident cohort field name to the connections layer so 
    # we can query network connections by cohort value on the front-end
    
    # Sites may correspond to Blood Collection Sites or Plasma Distribution Sites
    
    print("Adding join...")
    arcpy.management.AddJoin(connections_fc, connections_id_field, leads_fc, leads_incident_id_field, "KEEP_ALL")
    
    print("Calculating ID field...")
    new_field_name = "Likely"
    source_field_name = "{}.USER_Likely".format(str(leads_fc.split('\\')[-1]))
    arcpy.management.CalculateField(connections_fc, "Likely", f"!{source_field_name}!", "PYTHON3", '', "TEXT")
    print("Removing join...")
    arcpy.management.RemoveJoin(connections_fc, str(leads_fc.split('\\')[-1]))
    print("Step complete.")

# %%
def post_process_facilities_with_connection_info(connections_fc,
                                                 facilities_fc,
                                                 output_summary_table,
                                                 output_fgdb,
                                                 output_facilities_fc_name,
                                                 case_field="FacilityID",
                                                 facilities_id_field="FACILITY_ID"
                                                ):
    
    ### GOAL: To add the connection statistics for each facility for each cohort of donor
    print("Creating summary stats...")
    stats_table = arcpy.analysis.Statistics(connections_fc, output_summary_table, 
                                            "Total_TravelTime MEAN;Total_TravelTime MEDIAN;Total_TravelTime MAX;Total_TravelTime MIN;Total_TravelTime RANGE;Total_TravelTime STD;Total_Miles MEAN;Total_Miles MEDIAN;Total_Miles MAX;Total_Miles MIN;Total_Miles RANGE;Total_Miles STD", 
                                            case_field).getOutput(0)
    print("Joining tables...")
    arcpy.management.AddJoin(facilities_fc, facilities_id_field, stats_table, case_field, "KEEP_ALL")
    
    print("Exporting output...")
    out_facilities_fc = arcpy.conversion.FeatureClassToFeatureClass(facilities_fc, 
                                                                    output_fgdb, 
                                                                    output_facilities_fc_name).getOutput(0)
        
    return out_facilities_fc

# %%
def post_process_incidents_with_facilities(leads_fc, connections_fc, 
                                           output_fgdb, output_leads_fc_name,
                                           leads_id_field="INCIDENT_ID", connections_fc_field="IncidentID"
                                          ):
    
    # Set attribute indices
    print("Setting attribute indices...")
    arcpy.management.AddIndex(leads_fc, leads_id_field, "ID_Index", "UNIQUE", "ASCENDING")
    arcpy.management.AddIndex(connections_fc, connections_fc_field, "ID_Index", "UNIQUE", "ASCENDING")
    
    # Join connections to incidents
    print("Joining tables...")
    arcpy.management.AddJoin(leads_fc, leads_id_field, connections_fc, connections_fc_field, "KEEP_ALL")
    
    print("Exporting output...")
    out_leads_fc = arcpy.conversion.FeatureClassToFeatureClass(leads_fc, 
                                                               output_fgdb, 
                                                               output_leads_fc_name).getOutput(0)
    
    return leads_fc

# %%
def apply_symbology():
    arcpy.management.ApplySymbologyFromLayer(r"4 20 Data Update\FC_Leads", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\Blood Collection Sites- Not Selected.lyrx", None, "MAINTAIN")
    arcpy.management.ApplySymbologyFromLayer(r"4 20 Data Update\FC_Leads", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\Blood Collection Sites- Not Selected.lyrx", None, "MAINTAIN")
    arcpy.management.ApplySymbologyFromLayer(r"4 20 Data Update\FC_Leads", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\Blood Collection Sites- Not Selected.lyrx", None, "MAINTAIN")
    pass

# %%
def process_eap_sites_csv(input_csv,
                          id_field,
                          address_field,
                          city_field,
                          state_field,
                          zipcode_field,
                          workspace_fgdb,
                          output_table_name,
                          output_fc_path,
                          address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc"
                         ):
    
    ### GOAL: To geocode csv with incidents for ARC CCP Process
    # Incidents may correspond to Donor Leads or Plasma Need Locations
    
    # Use csv reader to find csv header row
    print("Finding header row...")
    with open(input_csv) as fin:
        reader = csv.reader(fin)
        idx = next(idx for idx, row in enumerate(reader) if len(row)>1)
        
    # Use pandas to pre-process the csv
    df = pd.read_csv(input_csv, skiprows=idx)
    
    print("Exporting to local temp CSV...")
    temp_csv_name = "temp_{0}.csv".format(str(uuid4()))
    df.to_csv(temp_csv_name)
        
    # Convert excel sheet to FGDB table
    print("Converting to table...")
    table = arcpy.conversion.TableToTable(temp_csv_name, workspace_fgdb, output_table_name).getOutput(0)
    
    print("Removing temp CSV...")
    os.remove(temp_csv_name)
    
    # Geocode FGDB Table using address fields
    print("Converting to feature class...")
    need_fc = arcpy.geocoding.GeocodeAddresses(table, 
                                               address_locator, 
                                               f"Address {address_field} VISIBLE NONE;City {arcpy.ValidateFieldName(city_field)} VISIBLE NONE;State {arcpy.ValidateFieldName(state_field)} VISIBLE NONE;ZIP_Code {arcpy.ValidateFieldName(zipcode_field)} VISIBLE NONE", 
                                               output_fc_path, 
                                               "STATIC", None, '', 
                                               "Subaddress;'Point Address';'Street Address';'Distance Marker';Intersection;'Street Name';'Primary Postal';'Postal Locality';'Postal Extension'").getOutput(0)
        
    return need_fc

# %%
def process_eapsites_demand(in_sites_fc_path, in_sites_id_field, in_needs_fc_path, in_needs_id_field, out_need_count_field_name):
    
    # Create the out_need_count field if it doesn't already exist
    if len(arcpy.ListFields(in_sites_fc_path, out_need_count_field_name)) == 0:
        print("Adding output field {}...".format(out_need_count_field_name))
        arcpy.AddField_management(in_sites_fc_path, out_need_count_field_name, "LONG")
    else:
        print("Using existing field {}...".format(out_need_count_field_name))

    need_sedf = pd.DataFrame.spatial.from_featureclass(in_needs_fc_path)

    # For each site
    with arcpy.da.UpdateCursor(in_sites_fc_path, [in_sites_id_field, out_need_count_field_name]) as cursor:
        for row in cursor:
            print(f"Current ID: {str(row[0])}")

            # Query for current site ID
            eap_count = need_sedf.loc[need_sedf[in_needs_id_field] == row[0]].shape[0]

            # Write count to site ID entry
            row[1] = eap_count
            cursor.updateRow(row)

    print("Completed.")

# %%
in_sites_fc_path = "C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\FC_EAPSites_200421"
in_sites_id_field = "USER_ExternalRefEntryID"
in_needs_fc_path = "C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\FC_Need_200421"
in_needs_id_field = "USER_ExternalRefID"
out_need_count_field_name = "EAP_Count"

process_eapsites_demand(in_sites_fc_path, in_sites_id_field, in_needs_fc_path, in_needs_id_field, out_need_count_field_name)
# Out:
# Using existing field EAP_Count...
# Current ID: ARC006E63ALVa
# Current ID: ARC036B1ANMEa
# Current ID: ARC009N8FTCLa
# Current ID: ARC019060800a
# Current ID: ARC055B8DESOa
# Current ID: ARC049T0300Ja
# Current ID: ARC022XBBa
# Current ID: ARC049T0046Ta
# Current ID: ARC036B3BONSa
# Current ID: ARC001B2BROKa
# Current ID: ARC022BYMa
# Current ID: ARC006B2CALIa
# Current ID: ARC022XHFa
# Current ID: ARC0122395a
# Current ID: ARC0122397a
# Current ID: ARC0122360a
# Current ID: ARC007000100a
# Current ID: ARC022NJCNSTa
# Current ID: ARC0337007a
# Current ID: ARC053B1CHILa
# Current ID: ARC011B1CHNEa
# Current ID: ARC022NNJCLAa
# Current ID: ARC006B6CPDHa
# Current ID: ARC038B3BRYNa
# Current ID: ARC022CTRa
# Current ID: ARC041A48010a
# Current ID: ARC022EMMa
# Current ID: ARC006PZ0932a
# Current ID: ARC038B7ELKHa
# Current ID: ARC017NM017a
# Current ID: ARC017WYOMa
# Current ID: ARC017PRINa
# Current ID: ARC017RIDGa
# Current ID: ARC017FVSDa
# Current ID: ARC036B1GEORa
# Current ID: ARC001B2GLENa
# Current ID: ARC001B7059Ha
# Current ID: ARC040B0GOTTa
# Current ID: ARC020LVSHHMa
# Current ID: ARC017HCMCa
# Current ID: ARC0041803a
# Current ID: ARC0041802a
# Current ID: ARC032B2OCOFa
# Current ID: ARC022NNJHMCa
# Current ID: ARC041A20126a
# Current ID: ARC01850HURLa
# Current ID: ARC022RMCa
# Current ID: ARC021P00211a
# Current ID: ARC006B9KWLAa
# Current ID: ARC001B1KENMa
# Current ID: ARC006BCLAGOa
# Current ID: ARC011B8LOGHa
# Current ID: ARC006B1DOCLa
# Current ID: ARC022LVHMa
# Current ID: ARC030B15001a
# Current ID: ARC022LVHTSa
# Current ID: ARC030B14001a
# Current ID: ARC036B1LEXIa
# Current ID: ARC0045108a
# Current ID: ARC084B4MARNa
# Current ID: ARC017CL253a
# Current ID: ARC036B1MCLEa
# Current ID: ARC049T0013Ta
# Current ID: ARC049T3901Ta
# Current ID: ARC006B8GDNAa
# Current ID: ARC011B2MMBLa
# Current ID: ARC001B1MERCa
# Current ID: ARC0045109a
# Current ID: ARC040B0MERCa
# Current ID: ARC011B1SASLa
# Current ID: ARC0041608a
# Current ID: ARC042C00019a
# Current ID: ARC01870MMRMa
# Current ID: ARC0337011a
# Current ID: ARC0122392a
# Current ID: ARC022NNJMMCa
# Current ID: ARC0041047a
# Current ID: ARC016COL014a
# Current ID: ARC01850MUNSa
# Current ID: ARC009B1METHa
# Current ID: ARC009N8NCMCa
# Current ID: ARC001003102a
# Current ID: ARC006E63PALa
# Current ID: ARC022PAOa
# Current ID: ARC049T1313Ta
# Current ID: ARC021P00102a
# Current ID: ARC022PHXa
# Current ID: ARC003B3ATHNa
# Current ID: ARC003B6PMIDa
# Current ID: ARC006B6PRESa
# Current ID: ARC006B5POMVa
# Current ID: ARC009N8PRESa
# Current ID: ARC036B1TUOMa
# Current ID: ARC006BVTARZa
# Current ID: ARC0045222a
# Current ID: ARC006BRREDLa
# Current ID: ARC0332680a
# Current ID: ARC022RIDa
# Current ID: ARC038B7RILEa
# Current ID: ARC041A46001a
# Current ID: ARC021P00306a
# Current ID: ARC020S98SLRa
# Current ID: ARC001B1SAMAa
# Current ID: ARC084B5SJGHa
# Current ID: ARC001B2SARAa
# Current ID: ARC006E63SCCa
# Current ID: ARC006E63SCEa
# Current ID: ARC006E63SCMa
# Current ID: ARC006E63SHVa
# Current ID: ARC006E63GROa
# Current ID: ARC001B1SISTa
# Current ID: ARC001B1STJOa
# Current ID: ARC021P00521a
# Current ID: ARC0122535a
# Current ID: ARC001B2SCHAa
# Current ID: ARC021P00203a
# Current ID: ARC042C0075Ba
# Current ID: ARC0337018a
# Current ID: ARC017SHOKa
# Current ID: ARC020B9JAMEa
# Current ID: ARC042C00083a
# Current ID: ARC001B1SLCHa
# Current ID: ARC006B1STMYa
# Current ID: ARC0337019a
# Current ID: ARC011B1SMYCa
# Current ID: ARC001B1SPETa
# Current ID: ARC038B7SVINa
# Current ID: ARC019051850a
# Current ID: ARC003B7TANNa
# Current ID: ARC022TEMa
# Current ID: ARC049T0063Ca
# Current ID: ARC006B8TORRa
# Current ID: ARC006E63TRIa
# Current ID: ARC013B3SJOPa
# Current ID: ARC0041051a
# Current ID: ARC006B3UCIMa
# Current ID: ARC036V3UHGAa
# Current ID: ARC049T0141Ga
# Current ID: ARC022VADEa
# Current ID: ARC035N1VCUa
# Current ID: ARC053B1ARLNa
# Current ID: ARC032B5WAPNa
# Current ID: ARC0123818a
# Current ID: ARC003B1DGLSa
# Current ID: ARC001B2WPHCa
# Current ID: ARC0337022a
# Current ID: MC114
# Current ID: MC203
# Current ID: MC24
# Current ID: MC294
# Current ID: MC354
# Current ID: MC383
# Current ID: MC51
# Current ID: MC999
# Current ID: MC998
# Current ID: MC997
# Current ID: MC996
# Current ID: MC994
# Current ID: MC993
# Current ID: MC992
# Current ID: MC99
# Current ID: MC989
# Current ID: MC985
# Current ID: MC982
# Current ID: MC979
# Current ID: MC974
# Current ID: MC973
# Current ID: MC972
# Current ID: MC969
# Current ID: MC963
# Current ID: MC958
# Current ID: MC956
# Current ID: MC954
# Current ID: MC946
# Current ID: MC943
# Current ID: MC936
# Current ID: MC931
# Current ID: MC929
# Current ID: MC926
# Current ID: MC925
# Current ID: MC924
# Current ID: MC920
# Current ID: MC918
# Current ID: MC916
# Current ID: MC91
# Current ID: MC908
# Current ID: MC902
# Current ID: MC901
# Current ID: MC894
# Current ID: MC89
# Current ID: MC882
# Current ID: MC88
# Current ID: MC870
# Current ID: MC87
# Current ID: MC868
# Current ID: MC864
# Current ID: MC861
# Current ID: MC859
# Current ID: MC858
# Current ID: MC857
# Current ID: MC853
# Current ID: MC851
# Current ID: MC850
# Current ID: MC847
# Current ID: MC839
# Current ID: MC835
# Current ID: MC834
# Current ID: MC833
# Current ID: MC827
# Current ID: MC82
# Current ID: MC805
# Current ID: MC803
# Current ID: MC791
# Current ID: MC788
# Current ID: MC787
# Current ID: MC786
# Current ID: MC782
# Current ID: MC775
# Current ID: MC774
# Current ID: MC772
# Current ID: MC761
# Current ID: MC759
# Current ID: MC758
# Current ID: MC755
# Current ID: MC741
# Current ID: MC733
# Current ID: MC722
# Current ID: MC714
# Current ID: MC708
# Current ID: MC700
# Current ID: MC697
# Current ID: MC692
# Current ID: MC681
# Current ID: MC680
# Current ID: MC670
# Current ID: MC659
# Current ID: MC649
# Current ID: MC565
# Current ID: MC559
# Current ID: MC552
# Current ID: MC549
# Current ID: MC538
# Current ID: MC533
# Current ID: MC530
# Current ID: MC525
# Current ID: MC524
# Current ID: MC522
# Current ID: MC521
# Current ID: MC508
# Current ID: MC5
# Current ID: MC499
# Current ID: MC498
# Current ID: MC496
# Current ID: MC495
# Current ID: MC490
# Current ID: MC486
# Current ID: MC483
# Current ID: MC461
# Current ID: MC455
# Current ID: MC454
# Current ID: MC448
# Current ID: MC430
# Current ID: MC429
# Current ID: MC428
# Current ID: MC427
# Current ID: MC426
# Current ID: MC424
# Current ID: MC422
# Current ID: MC42
# Current ID: MC416
# Current ID: MC414
# Current ID: MC401
# Current ID: MC396
# Current ID: MC391
# Current ID: MC387
# Current ID: MC384
# Current ID: MC382
# Current ID: MC380
# Current ID: MC373
# Current ID: MC370
# Current ID: MC369
# Current ID: MC363
# Current ID: MC362
# Current ID: MC357
# Current ID: MC353
# Current ID: MC343
# Current ID: MC33
# Current ID: MC326
# Current ID: MC324
# Current ID: MC323
# Current ID: MC321
# Current ID: MC318
# Current ID: MC317
# Current ID: MC315
# Current ID: MC314
# Current ID: MC313
# Current ID: MC311
# Current ID: MC310
# Current ID: MC308
# Current ID: MC299
# Current ID: MC297
# Current ID: MC288
# Current ID: MC285
# Current ID: MC284
# Current ID: MC281
# Current ID: MC280
# Current ID: MC28
# Current ID: MC279
# Current ID: MC276
# Current ID: MC274
# Current ID: MC272
# Current ID: MC271
# Current ID: MC269
# Current ID: MC266
# Current ID: MC262
# Current ID: MC261
# Current ID: MC259
# Current ID: MC258
# Current ID: MC253
# Current ID: MC252
# Current ID: MC245
# Current ID: MC242
# Current ID: MC238
# Current ID: MC228
# Current ID: MC226
# Current ID: MC221
# Current ID: MC220
# Current ID: MC217
# Current ID: MC212
# Current ID: MC196
# Current ID: MC193
# Current ID: MC190
# Current ID: MC188
# Current ID: MC187
# Current ID: MC185
# Current ID: MC182
# Current ID: MC172
# Current ID: MC169
# Current ID: MC167
# Current ID: MC165
# Current ID: MC164
# Current ID: ARC022CHLa
# Current ID: MC138
# Current ID: MC131
# Current ID: MC124
# Current ID: MC120
# Current ID: MC119
# Current ID: MC109
# Current ID: MC108
# Current ID: MC1074
# Current ID: MC1071
# Current ID: MC1070
# Current ID: MC105
# Current ID: MC1035
# Current ID: MC1032
# Current ID: MC1031
# Current ID: MC1030
# Current ID: MC103
# Current ID: MC1027
# Current ID: MC1026
# Current ID: MC1024
# Current ID: MC1021
# Current ID: MC1011
# Current ID: MC1008
# Current ID: MC1007
# Current ID: MC1005
# Current ID: MC1004
# Current ID: MC1002
# Current ID: MC648
# Current ID: MC646
# Current ID: MC634
# Current ID: MC616
# Current ID: MC611
# Current ID: MC610
# Current ID: MC609
# Current ID: MC607
# Current ID: MC605
# Current ID: MC600
# Current ID: MC598
# Current ID: MC595
# Current ID: MC594
# Current ID: MC586
# Current ID: MC1697
# Current ID: MC1686
# Current ID: MC1678
# Current ID: MC1670
# Current ID: MC1668
# Current ID: MC1660
# Current ID: MC1656
# Current ID: MC1652
# Current ID: MC1651
# Current ID: MC1636
# Current ID: MC1632
# Current ID: MC1629
# Current ID: MC1626
# Current ID: MC1618
# Current ID: MC1613
# Current ID: MC1612
# Current ID: MC1607
# Current ID: MC1606
# Current ID: MC1590
# Current ID: MC1584
# Current ID: MC1576
# Current ID: MC1575
# Current ID: MC1573
# Current ID: MC1568
# Current ID: MC1563
# Current ID: MC1562
# Current ID: MC1560
# Current ID: MC1555
# Current ID: MC1552
# Current ID: MC1547
# Current ID: MC1529
# Current ID: MC1525
# Current ID: MC1520
# Current ID: MC1509
# Current ID: ARC002B34826a
# Current ID: MC1503
# Current ID: MC1472
# Current ID: MC1460
# Current ID: MC1447
# Current ID: MC1431
# Current ID: MC1423
# Current ID: MC1421
# Current ID: MC1417
# Current ID: MC1407
# Current ID: MC1406
# Current ID: MC1393
# Current ID: MC1388
# Current ID: MC1383
# Current ID: MC1379
# Current ID: MC1378
# Current ID: MC1377
# Current ID: MC1374
# Current ID: MC1372
# Current ID: MC1369
# Current ID: MC1363
# Current ID: MC1359
# Current ID: MC1358
# Current ID: MC1323
# Current ID: MC1320
# Current ID: MC1318
# Current ID: MC1315
# Current ID: MC1306
# Current ID: MC1295
# Current ID: MC1286
# Current ID: MC1273
# Current ID: MC1267
# Current ID: MC1265
# Current ID: MC1263
# Current ID: MC1259
# Current ID: MC1257
# Current ID: ARC022MISa
# Current ID: MC1253
# Current ID: MC1251
# Current ID: MC1250
# Current ID: MC1246
# Current ID: MC1245
# Current ID: MC1243
# Current ID: MC1231
# Current ID: MC1214
# Current ID: MC1212
# Current ID: MC1210
# Current ID: MC1206
# Current ID: MC1204
# Current ID: MC1203
# Current ID: MC1202
# Current ID: MC1201
# Current ID: MC1200
# Current ID: MC1185
# Current ID: MC1167
# Current ID: MC1166
# Current ID: MC1162
# Current ID: MC1157
# Current ID: MC1142
# Current ID: MC1141
# Current ID: MC1139
# Current ID: MC1138
# Current ID: MC1137
# Current ID: MC1122
# Current ID: MC1100
# Current ID: MC1098
# Current ID: MC1097
# Current ID: MC1093
# Current ID: MC1092
# Current ID: MC1089
# Current ID: MC1
# Current ID: MC574
# Current ID: MC1430
# Current ID: MC1426
# Current ID: MC1095
# Current ID: MC1705
# Current ID: MC1706
# Current ID: MC1709
# Current ID: MC1719
# Current ID: MC1730
# Current ID: MC1736
# Current ID: MC1737
# Current ID: MC1744
# Current ID: MC1767
# Current ID: MC1773
# Current ID: MC1780
# Current ID: MC1784
# Current ID: MC1786
# Current ID: MC1798
# Current ID: MC1809
# Current ID: MC1813
# Current ID: MC1815
# Current ID: MC1816
# Current ID: MC1827
# Current ID: MC1831
# Current ID: MC1836
# Current ID: MC1838
# Current ID: MC1839
# Current ID: MC1849
# Current ID: MC1851
# Current ID: MC1852
# Current ID: MC1854
# Current ID: MC1858
# Current ID: MC1859
# Current ID: MC1871
# Current ID: MC1873
# Current ID: MC1875
# Current ID: MC1881
# Current ID: MC1898
# Current ID: MC1900
# Current ID: MC1902
# Current ID: MC1907
# Current ID: MC1916
# Current ID: MC1919
# Current ID: MC1925
# Current ID: MC1926
# Current ID: MC1927
# Current ID: MC1928
# Current ID: ARC022XADa
# Current ID: ARC003B1ATMCa
# Current ID: ARC001B1AMCHa
# Current ID: ARC0337001a
# Current ID: ARC007001000a
# Current ID: ARC024000415a
# Current ID: ARC017ABTNWa
# Current ID: ARC022MAIa
# Current ID: ARC007000130a
# Current ID: ARC041E47217a
# Current ID: ARC0041611a
# Current ID: ARC0122275a
# Current ID: ARC055B8BMEAa
# Current ID: ARC022MCHa
# Current ID: ARC01816BRONa
# Current ID: ARC0122140a
# Current ID: ARC0122575a
# Current ID: ARC0122577a
# Current ID: ARC0122100a
# Current ID: ARC02920012a
# Current ID: ARC027B9CAMCa
# Current ID: ARC022COOa
# Current ID: ARC024001060a
# Current ID: ARC011B1DEPLa
# Current ID: ARC024001080a
# Current ID: ARC0031114a
# Current ID: ARC022DOYa
# Current ID: ARC006BCELADa
# Current ID: ARC022EINa
# Current ID: ARC001B1ECMCa
# Current ID: ARC038B7ESKEa
# Current ID: ARC021P00607a
# Current ID: ARC017HIBBa
# Current ID: ARC0122405a
# Current ID: ARC022MREa
# Current ID: ARC038B1SAMCa
# Current ID: ARC038B5SACPa
# Current ID: ARC038B7STFSa
# Current ID: ARC030B12001a
# Current ID: ARC041E47007a
# Current ID: ARC009B6NPLTa
# Current ID: ARC022NJMOUNa
# Current ID: ARC0123732a
# Current ID: ARC0337005a
# Current ID: ARC006B8HGENa
# Current ID: ARC01815JAEAa
# Current ID: ARC006B3HOAGa
# Current ID: ARC001007035a
# Current ID: ARC006B4HUNTa
# Current ID: ARC006B3HOIRa
# Current ID: ARC038B7METIa
# Current ID: ARC022UNDa
# Current ID: ARC0337848a
# Current ID: ARC006B3KOCAa
# Current ID: ARC084B2KAOKa
# Current ID: ARC038B7IUHIa
# Current ID: ARC006B3KIRVa
# Current ID: ARC006B2KLOSa
# Current ID: ARC022XAGa
# Current ID: ARC022LNKa
# Current ID: ARC030B29001a
# Current ID: ARC006B1MELBa
# Current ID: ARC022LVH17a
# Current ID: ARC009B4HASTa
# Current ID: ARC032H0MCNLa
# Current ID: ARC017MANSa
# Current ID: ARC003B4MCMAa
# Current ID: ARC017ALBLa
# Current ID: ARC049T6411Ta
# Current ID: ARC049T3301Ta
# Current ID: ARC041A43008a
# Current ID: ARC011B9MNMCa
# Current ID: ARC055B1SPRGa
# Current ID: ARC055B8MLBSa
# Current ID: ARC049T0063Ja
# Current ID: ARC0337012a
# Current ID: ARC011B4MBSUa
# Current ID: ARC038B7SBMEa
# Current ID: ARC041A40104a
# Current ID: ARC011B1MBSLa
# Current ID: ARC016COL023a
# Current ID: ARC0332589a
# Current ID: ARC016COL010a
# Current ID: ARC003B2NEGBa
# Current ID: ARC003B2NEGAa
# Current ID: ARC003B1NSDEa
# Current ID: ARC040B0NWCHa
# Current ID: ARC009B6OGLAa
# Current ID: ARC024000440a
# Current ID: ARC006B3FHPHa
# Current ID: ARC024000590a
# Current ID: ARC040B9STFRa
# Current ID: ARC006B3PLINa
# Current ID: ARC030B28001a
# Current ID: ARC022POTa
# Current ID: ARC036B1BAPTa
# Current ID: ARC036B1PARKa
# Current ID: ARC036B1RICHa
# Current ID: ARC011B1PWCHa
# Current ID: ARC003B5PHBEa
# Current ID: ARC006BESTJBa
# Current ID: ARC006BMSTJNa
# Current ID: ARC021P00005a
# Current ID: ARC055B8REGMa
# Current ID: ARC006B7HOLYa
# Current ID: ARC011B9REMCa
# Current ID: ARC022XRWa
# Current ID: ARC022XHHa
# Current ID: ARC021P00519a
# Current ID: ARC006B3SADDa
# Current ID: ARC001B1RPMIa
# Current ID: ARC006BZSANTa
# Current ID: ARC006E63MERa
# Current ID: ARC006E63SCVa
# Current ID: ARC006E63SHAa
# Current ID: ARC0043314a
# Current ID: ARC01872BUTTa
# Current ID: ARC017NM002a
# Current ID: ARC032B5FONDa
# Current ID: ARC001B2SCATa
# Current ID: ARC042C00075a
# Current ID: ARC01872BLODa
# Current ID: ARC011B4SJOLa
# Current ID: ARC017SJOSa
# Current ID: ARC022NJSTJHa
# Current ID: ARC020B5STLMa
# Current ID: ARC011B1CDRNa
# Current ID: ARC020B5STLUa
# Current ID: ARC01872SASMa
# Current ID: ARC022NJSTMPa
# Current ID: ARC013B1SMRYa
# Current ID: ARC0337035a
# Current ID: ARC009B6STERa
# Current ID: ARC021P00640a
# Current ID: ARC003B7VILLa
# Current ID: ARC019037850a
# Current ID: ARC019049800a
# Current ID: ARC0337015a
# Current ID: ARC041A40202a
# Current ID: ARC007000125a
# Current ID: ARC032B0IACYa
# Current ID: ARC042CB0081a
# Current ID: ARC027S7UNITa
# Current ID: ARC020LVUNMCa
# Current ID: ARC001003602a
# Current ID: ARC024000425a
# Current ID: ARC041R10035a
# Current ID: ARC011B8UMMCa
# Current ID: ARC035N1UNVAa
# Current ID: ARC050B1MCOHa
# Current ID: ARC006B1LBVTa
# Current ID: ARC084B1PAVAa
# Current ID: ARC049T0066Ta
# Current ID: ARC006B9SAWTa
# Current ID: ARC002B19392a
# Current ID: ARC003B1KENNa
# Current ID: ARC003B1PAULa
# Current ID: ARC0337016a
# Current ID: MC13
# Current ID: MC166
# Current ID: MC177
# Current ID: MC18
# Current ID: MC243
# Current ID: ARC036B1WACCa
# Current ID: MC25
# Current ID: MC289
# Current ID: MC3
# Current ID: MC8
# Current ID: MC250
# Current ID: MC995
# Current ID: MC987
# Current ID: MC981
# Current ID: MC980
# Current ID: MC971
# Current ID: MC967
# Current ID: MC964
# Current ID: MC962
# Current ID: MC961
# Current ID: MC959
# Current ID: MC948
# Current ID: MC927
# Current ID: MC917
# Current ID: MC915
# Current ID: MC914
# Current ID: MC906
# Current ID: MC904
# Current ID: MC903
# Current ID: MC90
# Current ID: MC897
# Current ID: MC895
# Current ID: MC892
# Current ID: MC890
# Current ID: MC888
# Current ID: MC883
# Current ID: MC874
# Current ID: MC866
# Current ID: MC86
# Current ID: MC854
# Current ID: MC990
# Current ID: MC829
# Current ID: MC81
# Current ID: MC806
# Current ID: MC79
# Current ID: MC783
# Current ID: MC777
# Current ID: MC773
# Current ID: MC77
# Current ID: MC76
# Current ID: MC756
# Current ID: MC749
# Current ID: MC740
# Current ID: MC735
# Current ID: MC728
# Current ID: MC72
# Current ID: MC846
# Current ID: MC703
# Current ID: MC702
# Current ID: MC709
# Current ID: MC696
# Current ID: MC70
# Current ID: MC684
# Current ID: MC668
# Current ID: MC66
# Current ID: MC651
# Current ID: MC641
# Current ID: MC64
# Current ID: MC61
# Current ID: MC603
# Current ID: MC59
# Current ID: MC585
# Current ID: MC583
# Current ID: MC567
# Current ID: MC690
# Current ID: MC56
# Current ID: MC562
# Current ID: MC555
# Current ID: MC551
# Current ID: MC553
# Current ID: MC548
# Current ID: MC541
# Current ID: MC534
# Current ID: MC532
# Current ID: MC531
# Current ID: MC529
# Current ID: MC494
# Current ID: MC50
# Current ID: MC492
# Current ID: MC491
# Current ID: MC493
# Current ID: MC480
# Current ID: MC476
# Current ID: MC471
# Current ID: MC468
# Current ID: MC467
# Current ID: MC488
# Current ID: MC456
# Current ID: MC43
# Current ID: MC45
# Current ID: MC420
# Current ID: MC419
# Current ID: MC421
# Current ID: MC409
# Current ID: MC413
# Current ID: MC408
# Current ID: MC403
# Current ID: MC400
# Current ID: MC398
# Current ID: MC404
# Current ID: MC397
# Current ID: MC393
# Current ID: MC395
# Current ID: MC390
# Current ID: MC388
# Current ID: MC389
# Current ID: MC379
# Current ID: MC378
# Current ID: MC376
# Current ID: MC386
# Current ID: MC367
# Current ID: MC356
# Current ID: MC35
# Current ID: MC346
# Current ID: MC345
# Current ID: MC355
# Current ID: MC34
# Current ID: MC344
# Current ID: MC336
# Current ID: MC320
# Current ID: MC316
# Current ID: MC322
# Current ID: MC305
# Current ID: MC30
# Current ID: MC296
# Current ID: MC293
# Current ID: MC292
# Current ID: MC290
# Current ID: MC312
# Current ID: MC283
# Current ID: MC282
# Current ID: MC277
# Current ID: MC275
# Current ID: MC273
# Current ID: MC257
# Current ID: MC254
# Current ID: MC248
# Current ID: MC247
# Current ID: MC246
# Current ID: MC232
# Current ID: MC230
# Current ID: MC23
# Current ID: MC224
# Current ID: MC223
# Current ID: MC207
# Current ID: MC206
# Current ID: MC201
# Current ID: MC200
# Current ID: MC184
# Current ID: MC180
# Current ID: MC17
# Current ID: MC287
# Current ID: MC16
# Current ID: MC158
# Current ID: MC151
# Current ID: MC142
# Current ID: MC14
# Current ID: MC139
# Current ID: MC135
# Current ID: MC129
# Current ID: MC122
# Current ID: MC118
# Current ID: MC1082
# Current ID: MC1081
# Current ID: MC1077
# Current ID: MC1075
# Current ID: MC1072
# Current ID: MC1046
# Current ID: MC1028
# Current ID: MC1022
# Current ID: MC1020
# Current ID: MC1015
# Current ID: MC1013
# Current ID: MC1009
# Current ID: MC1006
# Current ID: MC1003
# Current ID: MC162
# Current ID: MC1001
# Current ID: MC1000
# Current ID: MC627
# Current ID: MC643
# Current ID: MC618
# Current ID: MC619
# Current ID: MC617
# Current ID: MC608
# Current ID: MC596
# Current ID: MC602
# Current ID: MC580
# Current ID: MC579
# Current ID: MC571
# Current ID: MC591
# Current ID: MC1691
# Current ID: MC1682
# Current ID: MC1675
# Current ID: MC1659
# Current ID: MC1654
# Current ID: MC1646
# Current ID: MC1642
# Current ID: MC1609
# Current ID: MC1603
# Current ID: MC1602
# Current ID: MC1595
# Current ID: MC1574
# Current ID: MC1570
# Current ID: MC1564
# Current ID: MC1539
# Current ID: MC1533
# Current ID: MC1531
# Current ID: MC1528
# Current ID: MC1521
# Current ID: MC1517
# Current ID: MC1507
# Current ID: MC1505
# Current ID: MC1502
# Current ID: MC1497
# Current ID: MC1475
# Current ID: MC1470
# Current ID: MC1463
# Current ID: MC1462
# Current ID: MC1459
# Current ID: MC1448
# Current ID: MC1445
# Current ID: MC1439
# Current ID: MC1411
# Current ID: MC1387
# Current ID: MC1381
# Current ID: MC1367
# Current ID: MC1361
# Current ID: MC1355
# Current ID: MC1353
# Current ID: MC1346
# Current ID: MC1345
# Current ID: MC1340
# Current ID: MC1339
# Current ID: MC1332
# Current ID: MC1331
# Current ID: MC1310
# Current ID: MC1308
# Current ID: MC1305
# Current ID: MC1304
# Current ID: MC1297
# Current ID: MC1702
# Current ID: MC1288
# Current ID: MC1287
# Current ID: MC1271
# Current ID: MC1269
# Current ID: MC1261
# Current ID: MC1260
# Current ID: MC1255
# Current ID: MC1242
# Current ID: MC1232
# Current ID: MC1227
# Current ID: MC1209
# Current ID: MC1184
# Current ID: MC1159
# Current ID: MC1153
# Current ID: MC1143
# Current ID: MC1140
# Current ID: MC1132
# Current ID: MC1099
# Current ID: MC1090
# Current ID: MC1105
# Current ID: MC1712
# Current ID: MC1715
# Current ID: MC1716
# Current ID: MC1718
# Current ID: MC1732
# Current ID: MC1738
# Current ID: MC1747
# Current ID: MC1764
# Current ID: MC1775
# Current ID: MC1781
# Current ID: MC1783
# Current ID: MC1276
# Current ID: MC1792
# Current ID: MC1800
# Current ID: MC1818
# Current ID: MC1819
# Current ID: MC1823
# Current ID: MC1826
# Current ID: MC1829
# Current ID: MC1833
# Current ID: MC1785
# Current ID: MC1850
# Current ID: MC1855
# Current ID: MC1863
# Current ID: MC1882
# Current ID: MC1883
# Current ID: MC1889
# Current ID: MC1895
# Current ID: MC1903
# Current ID: MC1904
# Current ID: MC1908
# Current ID: MC1912
# Current ID: MC1914
# Current ID: MC1921
# Current ID: MC1922
# Current ID: MC1924
# Current ID: MC1846
# Completed.

# %%
def process_needs_cumulative_time_table(fc_path, date_field, site_field, output_fc_path):
    
    def date_range(start, end):
        r = (end+datetime.timedelta(days=1)-start).days
        return [start+datetime.timedelta(days=i) for i in range(r)]
    
    # Import FC_Need into SEDF
    need_sedf = pd.DataFrame.spatial.from_featureclass(fc_path)

    # Determine first date
    start_date = need_sedf[date_field].sort_values().tolist()[0]

    # Determine last date
    last_date = need_sedf[date_field].sort_values().tolist()[-1]

    # Create list of days
    days_list = date_range(start_date, last_date)
    days_list

    # Create list of sites
    sites_list = need_sedf[site_field].unique().tolist()

    # Create new SEDF to receive each day's records
    new_sedf = need_sedf[[site_field, "SHAPE"]].iloc[0:1].copy()
    new_sedf = new_sedf.drop([0,0])
    new_sedf['New_Day_Count'] = 0
    new_sedf['Cumulative_Count'] = 0

    # For each site
    for site in sites_list:
        print("Processing site, {0}...".format(str(site)))

        # Get shape of Site
        site_shape = need_sedf.loc[need_sedf[site_field] == site].iloc[0]['SHAPE']
        print(site_shape)

        # Set variable for cumulative_counter
        cumulative_count = 0

        # For each day
        for day in days_list:

            # Query records for the site, for the day
            day_start = datetime.datetime.combine(day, datetime.datetime.min.time())
            day_end = datetime.datetime.combine(day, datetime.datetime.max.time())
            mask = (need_sedf[date_field] > day_start) & (need_sedf[date_field] <= day_end) & (need_sedf[site_field] == site)
            day_count = need_sedf.loc[mask].shape[0]
            if not day_count:
                day_count = 0

            cumulative_count += day_count

            # Write new row
            new_sedf = new_sedf.append({site_field: site, 
                                        'SHAPE': site_shape,
                                        'Date': day,
                                        'New_Day_Count': day_count, 
                                        'Cumulative_Count': cumulative_count}, ignore_index=True)

    print("Processing complete.")
    pass

# %%
fc_path = "C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\FC_Need_200421"
date_field = "USER_SubmissionDate"
site_field = "USER_ExternalRefID"

# Import FC_Need into SEDF
need_sedf = pd.DataFrame.spatial.from_featureclass(fc_path)

# Determine first date
start_date = need_sedf['USER_SubmissionDate'].sort_values().tolist()[0]

# Determine last date
last_date = need_sedf['USER_SubmissionDate'].sort_values().tolist()[-1]

# Create list of days
days_list = date_range(start_date, last_date)
days_list

# Create list of sites
sites_list = need_sedf[site_field].unique().tolist()

# Create new SEDF to receive each day's records
new_sedf = need_sedf[[site_field, "SHAPE"]].iloc[0:1].copy()
new_sedf = new_sedf.drop([0,0])
new_sedf['New_Day_Count'] = 0
new_sedf['Cumulative_Count'] = 0

# For each site
for site in sites_list:
    print("Processing site, {0}...".format(str(site)))
    
    # Get shape of Site
#     site_mask = (need_sedf[site_field] == site)
#     site_records = need_sedf.loc[mask]
#     need_sedf.loc[need_sedf[site_field] == site]
#     print(site_records)
    
#     site_shape = site_records.iloc[0]['SHAPE']
    site_shape = need_sedf.loc[need_sedf[site_field] == site].iloc[0]['SHAPE']
    print(site_shape)

    # Set variable for cumulative_counter
    cumulative_count = 0

    # For each day
    for day in days_list:
#         print("Processing day, {0}".format(str(day)))
        
        # Query records for the site, for the day
        day_start = datetime.datetime.combine(day, datetime.datetime.min.time())
        day_end = datetime.datetime.combine(day, datetime.datetime.max.time())
        mask = (need_sedf[date_field] > day_start) & (need_sedf[date_field] <= day_end) & (need_sedf[site_field] == site)
        day_count = need_sedf.loc[mask].shape[0]
        if not day_count:
#             print("Day count was null")
            day_count = 0
#         else:
# #             print("Day count: {0}".format(str(day_count)))
        cumulative_count += day_count
    
        # Write new row
        new_sedf = new_sedf.append({site_field: site, 
                                    'SHAPE': site_shape,
                                    'Date': day,
                                    'New_Day_Count': day_count, 
                                    'Cumulative_Count': cumulative_count}, ignore_index=True)
#         new_row = pd.Series({site_field: site, 'New_Day_Count': day_count, 'Cumulative_Count': cumulative_count})
#         new_sedf = pd.concat([new_sedf, new_row], ignore_index=True)

print("Processing complete.")
# Out:
# Processing site, ARC001003102a...
# {'x': -75.93594862642715, 'y': 42.09271247919867, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC001B1SAMAa...
# {'x': -73.67129562609148, 'y': 42.73400778153501, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 3
# Processing site, ARC001B1SLCHa...
# {'x': -74.01511408764424, 'y': 41.50351886540443, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 2
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count: 3
# Processing day, 2020-04-16 17:07:00
# Day count: 5
# Processing site, ARC001B1SPETa...
# {'x': -73.80378417529863, 'y': 42.65777022101997, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 4
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 2
# Processing site, ARC001B1STJOa...
# {'x': -78.78430324539767, 'y': 42.9149592228909, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC001B2BROKa...
# {'x': -72.97815388799074, 'y': 40.78001264257051, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC001B2GLENa...
# {'x': -73.64619818909432, 'y': 43.30703311109028, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count: 1
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 2
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC001B2GOODa...
# {'x': -73.29508698297707, 'y': 40.69578301747339, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 2
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count: 3
# Processing site, ARC001B2SFRNa...
# {'x': -73.669654554913, 'y': 40.80434199378908, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 2
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count: 4
# Processing day, 2020-04-16 17:07:00
# Day count: 4
# Processing site, ARC001B2SOTHa...
# {'x': -72.38054278981707, 'y': 40.885823290713404, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 2
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC001B2WPHCa...
# {'x': -73.76958508478305, 'y': 41.02636567803472, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count: 1
# Processing day, 2020-04-09 17:07:00
# Day count: 4
# Processing day, 2020-04-10 17:07:00
# Day count: 3
# Processing day, 2020-04-11 17:07:00
# Day count: 6
# Processing day, 2020-04-12 17:07:00
# Day count: 5
# Processing day, 2020-04-13 17:07:00
# Day count: 3
# Processing day, 2020-04-14 17:07:00
# Day count: 4
# Processing day, 2020-04-15 17:07:00
# Day count: 3
# Processing day, 2020-04-16 17:07:00
# Day count: 9
# Processing site, ARC001B7059Ha...
# {'x': -74.13385866314599, 'y': 41.112223553575234, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count: 2
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC001NYHQNSa...
# {'x': -73.82611580130236, 'y': 40.74731475976944, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC002B15446a...
# {'x': -96.59822623495205, 'y': 39.20165969793777, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC0031146a...
# {'x': -83.4908869253905, 'y': 31.470407616619298, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count: 2
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC003B7TANNa...
# {'x': -85.07254299266418, 'y': 33.5696725479508, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC0041020a...
# {'x': -71.37701592414476, 'y': 42.45287871708024, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC0041541a...
# {'x': -73.7071404507704, 'y': 40.753043357566014, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count: 2
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC006B1STMYa...
# {'x': -118.1866462621146, 'y': 33.780240201225354, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count: 1
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC006B2CALIa...
# {'x': -118.26548529421024, 'y': 34.03708770173711, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count: 1
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC006B5POMVa...
# {'x': -117.75232643841372, 'y': 34.07793266526136, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 1
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC006B6PRESa...
# {'x': -118.04758410312314, 'y': 33.96754729717111, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count: 3
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC006B9KWLAa...
# {'x': -118.37429252927609, 'y': 34.0374979697566, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count: 3
# Processing day, 2020-04-12 17:07:00
# Day count: 2
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC006E63GROa...
# {'x': -117.00949916275545, 'y': 32.77981249015539, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC006E63TRIa...
# {'x': -117.29172149794806, 'y': 33.18366759338579, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC007000100a...
# {'x': -111.00017047029024, 'y': 32.228892672759685, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count: 1
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC009N8LUKEa...
# {'x': -96.40625234107193, 'y': 42.518793145088694, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC011B1LUKEa...
# {'x': -90.5068159957608, 'y': 38.652368130985565, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC011B8LOGHa...
# {'x': -92.68438031559833, 'y': 38.11943599647515, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count: 2
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC013B3HFWBa...
# {'x': -83.40736011687511, 'y': 42.54157233669508, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 1
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC01850HURLa...
# {'x': -83.70489756477002, 'y': 43.02210207545153, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 3
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC019038140a...
# {'x': -86.42387444434934, 'y': 35.85887518484299, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 1
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 2
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC019051850a...
# {'x': -86.43377448720207, 'y': 36.39105321983129, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count: 1
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC019060800a...
# {'x': -88.6262401569569, 'y': 37.0733846329955, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC020LVNVISa...
# {'x': -115.12347911606764, 'y': 36.19578319643847, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 3
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022BYMa...
# {'x': -75.32024145188069, 'y': 40.01872331323142, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count: 3
# Processing day, 2020-04-07 17:07:00
# Day count: 1
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022CHCa...
# {'x': -75.60034717777921, 'y': 39.97293881707384, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022KIMa...
# {'x': -74.21742510028736, 'y': 40.07389618296355, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 6
# Processing site, ARC022LVHMa...
# {'x': -75.40359226487033, 'y': 40.65467697356456, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC022NJCNSTa...
# {'x': -74.31061651453973, 'y': 40.23657555152158, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count: 1
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022NJHOLYa...
# {'x': -74.00876892184743, 'y': 40.88217750119185, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022NNJCHHa...
# {'x': -74.05040295233357, 'y': 40.73441230148762, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 3
# Processing site, ARC022NNJCLAa...
# {'x': -74.17489594039455, 'y': 40.78615384032855, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count: 4
# Processing day, 2020-04-09 17:07:00
# Day count: 1
# Processing day, 2020-04-10 17:07:00
# Day count: 14
# Processing day, 2020-04-11 17:07:00
# Day count: 5
# Processing day, 2020-04-12 17:07:00
# Day count: 1
# Processing day, 2020-04-13 17:07:00
# Day count: 3
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count: 4
# Processing day, 2020-04-16 17:07:00
# Day count: 4
# Processing site, ARC022NNJHACa...
# {'x': -74.05792996939175, 'y': 40.884026037872445, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 4
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022NNJHMCa...
# {'x': -74.85755836522554, 'y': 40.53159428165185, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count: 2
# Processing site, ARC022NNJJFKa...
# {'x': -74.35132860682893, 'y': 40.55773370644647, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC022NNJMMCa...
# {'x': -73.98364584248083, 'y': 40.295467639521064, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022NNJRHWa...
# {'x': -74.29029659910793, 'y': 40.61204757793445, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022NNJWGHa...
# {'x': -74.20326153439152, 'y': 40.94777723573196, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 2
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022RMCa...
# {'x': -75.05916189830214, 'y': 39.44750339516662, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 5
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 1
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022TEMa...
# {'x': -75.15219596537071, 'y': 40.00467280380792, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 3
# Processing day, 2020-04-15 17:07:00
# Day count: 3
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, ARC022XBBa...
# {'x': -75.14247191804378, 'y': 38.77124208115822, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 2
# Processing site, ARC022XHFa...
# {'x': -74.75272093821991, 'y': 40.23606504776484, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, ARC024000470a...
# {'x': -85.7219061184718, 'y': 38.214995774436545, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# ...
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC64...
# {'x': -91.55391271499906, 'y': 41.66197414169437, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC651...
# {'x': -89.58750779694651, 'y': 40.704046789728636, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, MC684...
# {'x': -117.16793335623868, 'y': 32.6942470768422, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC591...
# {'x': -88.14451490084122, 'y': 42.05538429115319, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, MC696...
# {'x': -84.50993600324318, 'y': 38.03023848401989, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count: 1
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC690...
# {'x': -86.03948103352212, 'y': 39.90487447517796, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 1
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC702...
# {'x': -111.7216879044725, 'y': 33.364218520769214, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC703...
# {'x': -119.72219307544935, 'y': 34.43031742560976, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 1
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC709...
# {'x': -115.09854190858152, 'y': 36.21434199648701, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 2
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC740...
# {'x': -97.59813251370377, 'y': 35.60904232524422, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC77...
# {'x': -73.80306387319837, 'y': 41.08221915559068, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count: 16
# Processing day, 2020-04-15 17:07:00
# Day count: 21
# Processing day, 2020-04-16 17:07:00
# Day count: 19
# Processing site, MC829...
# {'x': -108.72718810204856, 'y': 35.512306020007884, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC854...
# {'x': -86.04597849501079, 'y': 39.900715447960636, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC86...
# {'x': -122.31020147951398, 'y': 47.61008364784317, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null
# Processing site, MC90...
# {'x': -73.8444298373663, 'y': 40.85097340759779, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count: 1
# Processing day, 2020-04-14 17:07:00
# Day count: 2
# Processing day, 2020-04-15 17:07:00
# Day count: 1
# Processing day, 2020-04-16 17:07:00
# Day count: 2
# Processing site, MC948...
# {'x': -74.0681563123631, 'y': 40.20834999635633, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count was null
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count: 3
# Processing day, 2020-04-16 17:07:00
# Day count: 1
# Processing site, MC967...
# {'x': -97.0668425358536, 'y': 47.887933847969805, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}
# Processing day, 2020-04-03 17:07:00
# Day count was null
# Processing day, 2020-04-04 17:07:00
# Day count was null
# Processing day, 2020-04-05 17:07:00
# Day count was null
# Processing day, 2020-04-06 17:07:00
# Day count was null
# Processing day, 2020-04-07 17:07:00
# Day count was null
# Processing day, 2020-04-08 17:07:00
# Day count was null
# Processing day, 2020-04-09 17:07:00
# Day count was null
# Processing day, 2020-04-10 17:07:00
# Day count: 1
# Processing day, 2020-04-11 17:07:00
# Day count was null
# Processing day, 2020-04-12 17:07:00
# Day count was null
# Processing day, 2020-04-13 17:07:00
# Day count was null
# Processing day, 2020-04-14 17:07:00
# Day count was null
# Processing day, 2020-04-15 17:07:00
# Day count was null
# Processing day, 2020-04-16 17:07:00
# Day count was null

# %%
new_sedf
# Out:
#      USER_ExternalRefID  ...                Date
# 0         ARC001003102a  ... 2020-04-03 17:07:00
# 1         ARC001003102a  ... 2020-04-04 17:07:00
# 2         ARC001003102a  ... 2020-04-05 17:07:00
# 3         ARC001003102a  ... 2020-04-06 17:07:00
# 4         ARC001003102a  ... 2020-04-07 17:07:00
# ...                 ...  ...                 ...
# 4559              MC967  ... 2020-04-12 17:07:00
# 4560              MC967  ... 2020-04-13 17:07:00
# 4561              MC967  ... 2020-04-14 17:07:00
# 4562              MC967  ... 2020-04-15 17:07:00
# 4563              MC967  ... 2020-04-16 17:07:00
#
# [4564 rows x 5 columns]

# %%
new_sedf.spatial.to_featureclass(r"C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\cumulative_table")
# Out:
# 'C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\cumulative_table'

# %%
new_sedf.spatial.to_featureclass(r"C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\cumulative_table_2")
# Out:
# 'C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\cumulative_table_2'

# %% [markdown]
# #### TODO: Connection Summary stats by COHORT

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Phase 1: Donor Leads and Blood Collection Sites

# %%
# Leads Processing for 4/20/20
LEADS_input_csv = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\ESRI - Leads.csv"
LEADS_address_field = "Address"
LEADS_city_field = "City"
LEADS_state_field = r"State_Province_Region"
LEADS_zipcode_field = "Zipcode1"
LEADS_country_field = "Country1"
LEADS_workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
LEADS_output_table_name = "Table_Leads_200422"
LEADS_output_fc_path = LEADS_workspace_fgdb+r"\FC_Leads_200422"

leads_fc = process_leads_csv(LEADS_input_csv, 
                             LEADS_address_field,
                             LEADS_city_field,
                             LEADS_state_field,
                             LEADS_zipcode_field,
                             LEADS_country_field,
                             LEADS_workspace_fgdb,
                             LEADS_output_table_name,
                             LEADS_output_fc_path,
                             address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                             incident_field=None,
                             symbology_layer=None,
                             process_cohort_field=True,
                             cohort_field="Likely",
                             process_US_only=True)
# Out:
# Finding header row...
#
# Cohort field value counts:
# No              18071
# Yes             17464
# I don't know     1133
# Name: Likely, dtype: int64
# Processing cohort field...
# New cohort value counts:
# No     19204
# Yes    17464
# Name: Likely, dtype: int64
#
# Country values:
# United States           36548
# Canada                     58
# United Kingdom             34
# India                       4
# Spain                       4
# France                      3
# Philippines                 3
# Mexico                      2
# Iraq                        2
# Portugal                    1
# Japan                       1
# New Zealand                 1
# South Korea                 1
# Australia                   1
# Bangladesh                  1
# Israel                      1
# Jersey                      1
# United Arab Emirates        1
# Argentina                   1
# Name: Country1, dtype: int64
# Using United States records...
#
# Exporting to local temp CSV...
# Converting to table...
# Removing temp CSV...
# Converting to incidents...
# Creating Incident ID field...

# %%
# Collection Site processing for 4/20/2020

input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Archived\Phase1_ARC_Sample_File_3.xlsx"
input_sheet_name = "CollectionSites"
address_field = "AddressLine1"
city_field = "City"
state_field = "State"
zipcode_field = "ZipCode"
output_facilities_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_CollectionSites_200420"
output_facilities_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_CollectionSites_200420"

facilities_fc = process_facilities(input_excel, 
                                   input_sheet_name,
                                   address_field,
                                   city_field,
                                   state_field,
                                   zipcode_field,
                                   output_facilities_table_path,
                                   output_facilities_fc_path,
                                   address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                                   facility_field=None,
                                   symbology_layer=None)
# Out:
# Converting to table...
# Converting to facilities...
# Creating Facility ID field...

# %%
# Leads to BCS Connections
workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_connections_name = "Connections_LeadstoBCS_200422"
routing_nd = r"C:\ArcGIS\Business Analyst\US_2019\Data\Streets Data\NorthAmerica.gdb\Routing\Routing_ND"

connections_fc = process_connections(facilities_fc, 
                                     leads_fc,
                                     workspace_fgdb,
                                     output_connections_name,
                                     routing_nd)
# Out:
# Creating NA Object...
# Adding Facilities...
# Adding Incidents...
# Solving...
# Exporting connections to disk...
# {'Facilities': 'Facilities', 'Incidents': 'Incidents', 'Barriers': 'Point Barriers', 'CFRoutes': 'Routes', 'PolylineBarriers': 'Line Barriers', 'PolygonBarriers': 'Polygon Barriers'}

# %%
connections_fc

# %%
# Post-process Connections
post_process_connections_with_lead_info(output_connections_name, leads_fc)
# Out:
# Adding join...
# Calculating ID field...
# Removing join...
# Step complete.

# %%
# Post-process BCS Summary Stats
# connections_fc = "Connections_Leads_to_BCS_200420"
# facilities_fc = "FC_CollectionSites_200420"
# leads_fc = "FC_Leads_200420"
output_summary_table = "in_memory\SummaryStats"
output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_facilities_fc_name = "FC_CollectionSites_200422_Processed"

post_process_facilities_with_connection_info(connections_fc,
                                             facilities_fc,
                                             output_summary_table,
                                             output_fgdb,
                                             output_facilities_fc_name)
# Out:
# Creating summary stats...
# Joining tables...
# Exporting output...
# 'C:\\Users\\albe9057\\Documents\\ArcGIS\\Projects\\ARC_Convalescent_Plasma\\ARC_Convalescent_Plasma.gdb\\FC_CollectionSites_200422_Processed'

# %%
# Post-process Leads Summary Stats
connections_fc = "Connections_LeadstoBCS_200422"
leads_fc = "FC_Leads_200422"
output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_leads_fc_name = "FC_Leads_200422_Processed"
leads_fc = post_process_incidents_with_facilities(leads_fc, connections_fc, output_fgdb, output_leads_fc_name)
# Out:
# Setting attribute indices...
# Joining tables...
# Exporting output...

# %% [markdown]
# ### Phase 2: Care Givers and Requests

# %%
workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
NEED_csv = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\ESRI - Demand Need.csv"
NEED_id_field = "ExternalRefID"
NEED_address_field = "Address"
NEED_city_field = "City"
NEED_state_field = "State"
NEED_zipcode_field = "ZipCode"
NEED_output_table_name = "Table_EAPNeed_200421"
NEED_output_fc_path = workspace_fgdb + r"\FC_EAPNeed_200421"

need_fc = process_eap_sites_csv(NEED_csv,
                                NEED_id_field,
                                NEED_address_field,
                                NEED_city_field,
                                NEED_state_field,
                                NEED_zipcode_field,
                                workspace_fgdb,
                                NEED_output_table_name,
                                NEED_output_fc_path,
                                address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc")

# %%
workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
EAPSITES_csv = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\ESRI - Demand Sites.csv"
EAPSITES_id_field = "ExternalRefEntryID"
EAPSITES_address_field = "Address"
EAPSITES_city_field = "City"
EAPSITES_state_field = "State"
EAPSITES_zipcode_field = "ZipCode"
EAPSITES_output_table_name = "Table_EAPSites_200421"
EAPSITES_output_fc_path = workspace_fgdb + r"\FC_EAPSites_200421"

EAPSITES_fc = process_eap_sites_csv(EAPSITES_csv,
                                    EAPSITES_id_field,
                                    EAPSITES_address_field,
                                    EAPSITES_city_field,
                                    EAPSITES_state_field,
                                    EAPSITES_zipcode_field,
                                    workspace_fgdb,
                                    EAPSITES_output_table_name,
                                    EAPSITES_output_fc_path,
                                    address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc")

# %% [markdown]
# #### Reference Cells

# %%
# Leads Processing for 4/17/2020
LEADS_input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\Phase1_ARC_Sample_File_4.xlsx"
LEADS_input_sheet_name = "Sheet1"
LEADS_address_field = "Address"
LEADS_city_field = "City"
LEADS_state_field = r"State/Province/Region"
LEADS_zipcode_field = r"Zipcode"
LEADS_output_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_Leads_200417_v2"
LEADS_output_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_Leads_200417_v2"

# Collection Site processing for 4/13/2020
BCS_input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Archived\Phase1_ARC_Sample_File_3.xlsx"
BCS_input_sheet_name = "CollectionSites"
BCS_address_field = "AddressLine1"
BCS_city_field = "City"
BCS_state_field = "State"
BCS_zipcode_field = "ZipCode"
BCS_output_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_CollectionSites_200413_v2"
BCS_output_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_CollectionSites_200413_v2"

# Leads to BCS Connections
workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
routing_nd = r"C:\ArcGIS\Business Analyst\US_2019\Data\Streets Data\NorthAmerica.gdb\Routing\Routing_ND"
CONN_output_connections_name = "Connections_Leads_to_BCS_200417_V2"

# Post-process Connections
connections_fc = "Connections_Leads_to_BCS_200417_V2"
leads_fc = "FC_Leads_200417_V2"

# Post-process BCS Summary Stats
connections_fc = "Connections_Leads_to_BCS_200417_V2"
facilities_fc = "FC_CollectionSites_200413_V2"
leads_fc = "FC_Leads_200417_V2"
output_summary_table = "in_memory\SummaryStats"
output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_facilities_fc_name = "FC_CollectionSites_200413_V2_Processed"

# Post-process Leads Summary Stats
connections_fc = "Connections_Leads_to_BCS_200417_V2"
leads_fc = "FC_Leads_200417_V2"
output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_leads_fc_name = "FC_Leads_200417_V2_Processed"

# %%
# # Leads Processing for 4/17/2020

# input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\Phase1_ARC_Sample_File_4.xlsx"
# input_sheet_name = "Sheet1"
# address_field = "Address"
# city_field = "City"
# state_field = r"State/Province/Region"
# zipcode_field = r"Zipcode"
# output_facilities_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_Leads_200417_v2"
# output_facilities_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_Leads_200417_v2"

# incidents_fc = process_incidents(input_excel, 
#                                  input_sheet_name,
#                                  address_field,
#                                  city_field,
#                                  state_field,
#                                  zipcode_field,
#                                  output_facilities_table_path,
#                                  output_facilities_fc_path,
#                                  address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
#                                  incident_field=None,
#                                  symbology_layer=None)

# %%
# # Leads to BCS Connections
# workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
# output_connections_name = "Connections_Leads_to_BCS_200417_V2"
# routing_nd = r"C:\ArcGIS\Business Analyst\US_2019\Data\Streets Data\NorthAmerica.gdb\Routing\Routing_ND"

# process_connections(facilities_fc, 
#                     incidents_fc,
#                     workspace_fgdb,
#                     output_connections_name,
#                     routing_nd)

# %%
# # Post-process Connections
# connections_fc = "Connections_Leads_to_BCS_200417_V2"
# leads_fc = "FC_Leads_200417_V2"
# post_process_connections_with_lead_info(connections_fc, leads_fc)

# %%
# # Post-process BCS Summary Stats

# connections_fc = "Connections_Leads_to_BCS_200417_V2"
# facilities_fc = "FC_CollectionSites_200413_V2"
# leads_fc = "FC_Leads_200417_V2"
# output_summary_table = "in_memory\SummaryStats"
# output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
# output_facilities_fc_name = "FC_CollectionSites_200413_V2_Processed"

# post_process_facilities_with_connection_info(connections_fc,
#                                              facilities_fc,
#                                              output_summary_table,
#                                              output_fgdb,
#                                              output_facilities_fc_name)

# %%
# # Post-process Leads Summary Stats
# connections_fc = "Connections_Leads_to_BCS_200417_V2"
# leads_fc = "FC_Leads_200417_V2"
# output_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
# output_leads_fc_name = "FC_Leads_200417_V2_Processed"
# leads_fc = post_process_incidents_with_facilities(leads_fc, connections_fc, output_fgdb, output_leads_fc_name)

# %% [markdown]
# ### Phase 2: EAPSites to EAPNeeds

# %%
# EAPSite processing for 4/17/2020

input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\Phase2_ARC_Sample_File_1.xlsx"
input_sheet_name = "EAPSites"
address_field = "Address"
city_field = "City"
state_field = r"State"
zipcode_field = r"ZipCode"
output_facilities_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_EAPSites_200417"
output_facilities_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_EAPSites_200417"

facilities_fc = process_facilities(input_excel, 
                                   input_sheet_name,
                                   address_field,
                                   city_field,
                                   state_field,
                                   zipcode_field,
                                   output_facilities_table_path,
                                   output_facilities_fc_path,
                                   address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                                   facility_field=None,
                                   symbology_layer=None)

# %%
# EAPNeed Processing for 4/17/2010

input_excel = r"C:\Users\albe9057\Documents\4_Sandbox_Projects\2004_ARC_COVID19_Plasma\Data\Operational\Phase2_ARC_Sample_File_1.xlsx"
input_sheet_name = "EAPNeed"
address_field = "Address"
city_field = "City"
state_field = r"State"
zipcode_field = r"ZipCode"
output_facilities_table_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\Table_EAPNeed_200417_v2"
output_facilities_fc_path = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb\FC_EAPNeed_200417_v2"

incidents_fc = process_incidents(input_excel, 
                                 input_sheet_name,
                                 address_field,
                                 city_field,
                                 state_field,
                                 zipcode_field,
                                 output_facilities_table_path,
                                 output_facilities_fc_path,
                                 address_locator=r"C:\ArcGIS\Business Analyst\US_2019\Data\Geocoding Data\USA_LocalComposite.loc",
                                 incident_field=None,
                                 symbology_layer=None)

# %%
# EAP Connections
workspace_fgdb = r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\ARC_Convalescent_Plasma.gdb"
output_connections_name = "Connections_EAPNeeds_to_EAPSites_200417"
routing_nd = r"C:\ArcGIS\Business Analyst\US_2019\Data\Streets Data\NorthAmerica.gdb\Routing\Routing_ND"

process_connections(facilities_fc, 
                    incidents_fc,
                    workspace_fgdb,
                    output_connections_name,
                    routing_nd)

# %% [markdown]
# ## Reference Code

# %%
arcpy.management.ApplySymbologyFromLayer("CollectionSites_FC_200413", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\CollectionSiteslyrx.lyrx", None, "DEFAULT")

# %%
arcpy.management.DeleteField("CollectionSites_FC_200413", "AddNum;AddNumFrom;AddNumTo;Addr_type;IN_Address;City;City;Country;Country;DisplayX;DisplayY;Distance;LangCode;Loc_name;Match_addr;Match_type;Postal;Rank;Region;RegionAbbr;Score;Side;StAddr;IN_State;Xmax;Xmin;Ymax;Ymin")

# %%
arcpy.management.ApplySymbologyFromLayer("DonorLeads_FC_200413", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\DonorLeadslyrx.lyrx", "VALUE_FIELD USER_Likely USER_Likely", "MAINTAIN")

# %%
arcpy.management.DeleteField("DonorLeads_FC_200413", "AddNum;AddNumFrom;AddNumTo;Addr_type;IN_Address;City;City;Country;DisplayX;DisplayY;Distance;LangCode;Loc_name;Match_addr;Match_type;USER_Postal___Zip_Code;Rank;Region;RegionAbbr;Score;Side;StAddr;USER_State___Province___Region;Status;StDir;StName;StPreDir;StPreType;StType;Subregion;Xmax;Xmin;Ymax;Ymin")

# %%
arcpy.management.ApplySymbologyFromLayer("Routes_FC_AllDLtoBCS_200413", r"C:\Users\albe9057\Documents\ArcGIS\Projects\ARC_Convalescent_Plasma\Connections_DonorstoCollectionSites.lyrx", None, "MAINTAIN")

# %% [markdown]
# C1. Collection Centers to Hospitals

# %% [markdown]
# ## D. Publish Outputs

# %% [markdown]
# ## E. Clustering Analysis

# %% [markdown]
# ## F. Threshold Analysis
